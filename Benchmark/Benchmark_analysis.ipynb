# %%
import pandas as pd
from Analysis_utils import compare_roll_distributions, plot_roll_distribution, plot_rolls_over_time, compare_rolls_over_time

# %%
game_data = pd.read_csv('Catan_benchmark_sim_2p_1000_rolls_20250517.csv')
game_data.head()
# Out:
#      Player  Dice_1  Dice_2  Total_roll
# 0  Player_1       2       6           8
# 1  Player_2       2       1           3
# 2  Player_1       2       1           3
# 3  Player_2       3       3           6
# 4  Player_1       2       1           3

# %%
Madi_rolls = game_data[game_data['Player'] == 'Player_1'].reset_index()
Theo_rolls = game_data[game_data['Player'] == 'Player_2'].reset_index()

# %%
plot_roll_distribution(game_data["Total_roll"])

# %%
plot_roll_distribution(Madi_rolls['Total_roll'], dice_count=2)

# %%
compare_roll_distributions(game_data['Dice_1'], game_data['Dice_2'], label1='Dice1', label2='Dice2')
# Out:
# Statistical Summary:
# Dice1: Mean = 3.44, Median = 3.00, Std = 1.68
# Dice2: Mean = 3.38, Median = 3.00, Std = 1.68

# %%
compare_roll_distributions(Madi_rolls['Total_roll'], Theo_rolls['Total_roll'], label1='Madi', label2='Theo')
# Out:
# Statistical Summary:
# Madi: Mean = 6.74, Median = 7.00, Std = 2.32
# Theo: Mean = 6.90, Median = 7.00, Std = 2.53

# %%
plot_rolls_over_time(game_data['Total_roll'])

# %%
compare_rolls_over_time(game_data['Dice_1'], game_data['Dice_2'], label1='Dice1', label2='Dice2')
# Out:
# Statistical Summary:
# Dice1: Mean = 3.44, Median = 3.0, Std Dev = 1.68
# Dice2: Mean = 3.38, Median = 3.0, Std Dev = 1.68
# Difference (Dice1 - Dice2):
#   Mean = 0.06, Std Dev = 2.34

# %%
compare_rolls_over_time(Madi_rolls['Total_roll'], Theo_rolls['Total_roll'], label1='Madi', label2='Theo')
# Out:
# Statistical Summary:
# Madi: Mean = 6.74, Median = 7.0, Std Dev = 2.32
# Theo: Mean = 6.90, Median = 7.0, Std Dev = 2.53
# Difference (Madi - Theo):
#   Mean = -0.16, Std Dev = 3.49
#   Robber moves: Madi: 90, Theo: 87
