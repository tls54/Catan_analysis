# %%
import pandas as pd
from Analysis_utils import compare_roll_distributions, plot_roll_distribution, plot_rolls_over_time, compare_rolls_over_time

# %%
game_data = pd.read_csv('Catan_game_2025-05-17.csv')
game_data.columns
# Out:
# Index(['Player', 'Dice_1', 'Dice_2', 'Total_roll'], dtype='object')

# %%
Madi_rolls = game_data[game_data['Player'] == 'Madi'].reset_index()
Theo_rolls = game_data[game_data['Player'] == 'Theo'].reset_index()

# %%
plot_roll_distribution(game_data["Total_roll"])

# %%
plot_roll_distribution(Madi_rolls['Total_roll'], dice_count=2)

# %%
compare_roll_distributions(game_data['Dice_1'], game_data['Dice_2'], label1='Dice1', label2='Dice2')
# Out:
# Statistical Summary:
# Dice1: Mean = 3.84, Median = 4.00, Std = 1.68
# Dice2: Mean = 3.37, Median = 3.00, Std = 1.79

# %%
compare_roll_distributions(Madi_rolls['Total_roll'], Theo_rolls['Total_roll'], label1='Madi', label2='Theo')
# Out:
# Statistical Summary:
# Madi: Mean = 7.57, Median = 7.00, Std = 2.36
# Theo: Mean = 6.86, Median = 7.00, Std = 2.00

# %%
plot_rolls_over_time(game_data['Total_roll'])

# %%
compare_rolls_over_time(game_data['Dice_1'], game_data['Dice_2'], label1='Dice1', label2='Dice2')
# Out:
# Statistical Summary:
# Dice1: Mean = 3.84, Median = 4.0, Std Dev = 1.68
# Dice2: Mean = 3.37, Median = 3.0, Std Dev = 1.79
# Difference (Dice1 - Dice2):
#   Mean = 0.47, Std Dev = 2.69

# %%
compare_rolls_over_time(Madi_rolls['Total_roll'], Theo_rolls['Total_roll'], label1='Madi', label2='Theo')
# Out:
# Statistical Summary:
# Madi: Mean = 7.57, Median = 7.0, Std Dev = 2.36
# Theo: Mean = 6.86, Median = 7.0, Std Dev = 2.00
# Difference (Madi - Theo):
#   Mean = 0.71, Std Dev = 2.91
#   Robber moves: Madi: 10, Theo: 12
